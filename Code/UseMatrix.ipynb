# %% [markdown]
# <a href="https://colab.research.google.com/github/hrbae/DS_Algorithm/blob/main/Code/UseMatrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Google drive를 마운트
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Colab\ Notebooks/Data_Structures
# Out:
# /content/drive/MyDrive/Colab Notebooks/Data_Structures

# %%
# !ls
# Out:
# ClassUse.ipynb		  D2_rail_way.ipynb	 DS_Class
# D2_ArraySum.ipynb	  D2_RopeIntranet.ipynb  MyOwn
# D2_BrokenKeyboard.ipynb   D3_Djikstra.ipynb	 __pycache__
# D2_D3_Array.ipynb	  D3_Fibonacci.ipynb	 Suma.ipynb
# D2_Matrix_test.ipynb	  D3_LCS.ipynb		 Untitled
# D2_ParenthMatching.ipynb  D3_matrixChain.ipynb	 useClass.ipynb
# D2_PrimeNumber.ipynb	  D3_Sorting.ipynb	 UseVector.ipynb

# %%
from DS_Class.MatrixCalc import MatOperation

# %%
mo=MatOperation()
R=[[0.6, 0.33, 0.07],[0.52, 0.07, 0.41], [0.07, 0.07, 0.86]]
I = [[1/3, 1/3, 1/3]]


mo.MarkovProcess(I, R, 100)
# Out:
# Initial sate:
# At time:  1 	 [[0.3966666666666666, 0.15666666666666668, 0.44666666666666666]]
# At time:  2 	 [[0.3507333333333333, 0.17313333333333333, 0.4761333333333333]]
# At time:  3 	 [[0.33379866666666663, 0.16119066666666665, 0.5050106666666666]]
# At time:  4 	 [[0.31944909333333327, 0.15678765333333333, 0.5237632533333333]]
# At time:  5 	 [[0.30986246346666657, 0.15305676426666665, 0.5370807722666666]]
# At time:  6 	 [[0.3031026495573333, 0.1505642405013333, 0.5463331099413333]]
# At time:  7 	 [[0.29839831249098664, 0.14880668888490667, 0.5527949986241066]]
# At time:  8 	 [[0.29511411561843093, 0.14758356124765654, 0.5573023231339125]]
# At time:  9 	 [[0.29282308383921385, 0.14672967006079204, 0.5604472460999941]]
# At time:  10 	 [[0.29122458596213974, 0.1461340017981956, 0.5626414122396646]]
# At time:  11 	 [[0.2901093313691221, 0.14571839235015632, 0.5641722762807215]]
# At time:  12 	 [[0.28933122218320506, 0.14542842615597174, 0.5652403516608232]]
# ...
